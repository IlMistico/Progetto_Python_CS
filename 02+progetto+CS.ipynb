# %%
import pandas as pd
import numpy as np

cr = pd.read_csv("C:/Users/matti/Desktop/UNIMIB/Magistrale/Materie Primo semestre/Foundation of CS/progetto/movies/tmdb_5000_credits.csv")
mv = pd.read_csv("C:/Users/matti/Desktop/UNIMIB/Magistrale/Materie Primo semestre/Foundation of CS/progetto/movies/tmdb_5000_movies.csv")

# %%
cr
# Out:
#       movie_id                                        title  \
# 0        19995                                       Avatar
# 1          285     Pirates of the Caribbean: At World's End
# 2       206647                                      Spectre
# 3        49026                        The Dark Knight Rises
# 4        49529                                  John Carter
# 5          559                                 Spider-Man 3
# 6        38757                                      Tangled
# 7        99861                      Avengers: Age of Ultron
# 8          767       Harry Potter and the Half-Blood Prince
# 9       209112           Batman v Superman: Dawn of Justice
# 10        1452                             Superman Returns
# 11       10764                            Quantum of Solace
# 12          58   Pirates of the Caribbean: Dead Man's Chest
# 13       57201                              The Lone Ranger
# 14       49521                                 Man of Steel
# ...

# %%
mv
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 5     258000000  [{"id": 14, "name": "Fantasy"}, {"id": 28, "na...
# 6     260000000  [{"id": 16, "name": "Animation"}, {"id": 10751...
# 7     280000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 8     250000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 9     250000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 10    270000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 11    200000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# 12    200000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# ...

# %%
# 1. For each movie, compute the number of cast members

n_attori = []
for i in range(len(cr)):
    cast = pd.read_json(cr["cast"][i])
    title = cr["title"][i]
    n_attori.append("for " + title + " the number of actors is " + str(len(cast)))
    print(n_attori[i])
# Out:
# for Avatar the number of actors is 83
# for Pirates of the Caribbean: At World's End the number of actors is 34
# for Spectre the number of actors is 83
# for The Dark Knight Rises the number of actors is 158
# for John Carter the number of actors is 27
# for Spider-Man 3 the number of actors is 143
# for Tangled the number of actors is 13
# for Avengers: Age of Ultron the number of actors is 72
# for Harry Potter and the Half-Blood Prince the number of actors is 49
# for Batman v Superman: Dawn of Justice the number of actors is 152
# for Superman Returns the number of actors is 18
# for Quantum of Solace the number of actors is 32
# for Pirates of the Caribbean: Dead Man's Chest the number of actors is 33
# for The Lone Ranger the number of actors is 60
# for Man of Steel the number of actors is 33
# for The Chronicles of Narnia: Prince Caspian the number of actors is 21
# for The Avengers the number of actors is 115
# ...

# %%
# 2. How many movies do not have a homepage?

mv1 = mv.dropna(subset = ["homepage"])
movies_no_homepage = len(mv) - len(mv1) 
movies_no_homepage
# Out:
# 3091

# %%
# 3. For each year, how many movies do not have a homepage?

mv2 = mv[mv.homepage.isnull()]
mv2["year"] = mv2["release_date"].str.extract("(.*)-.*-.*", expand = True)
mv2.groupby("year").size()
# Out:
# C:\Users\matti\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# year
# 1916      1
# 1925      1
# 1927      1
# 1929      2
# 1930      1
# 1932      1
# 1933      2
# 1934      1
# 1935      1
# 1936      2
# 1937      1
# 1938      2
# 1939      2
# 1940      4
# 1941      1
# 1942      1
# 1944      2
# 1945      4
# 1946      3
# 1947      3
# 1948      3
# 1949      2
# 1950      1
# 1951      3
# 1952      4
# 1953      4
# 1954      4
# 1955      2
# 1956      3
# 1957      2
#        ...
# 1987     29
# 1988     28
# 1989     28
# 1990     24
# 1991     29
# 1992     29
# 1993     44
# 1994     50
# 1995     64
# 1996     86
# 1997    102
# 1998    119
# ...

# %%
# 4. Extract the domain of each homepage

def extract_domain(homepage):
    words = homepage.split("/")
    return words[2].split('.')[-1]

mv1["domains"] = mv1["homepage"].apply(extract_domain)
mv1[["original_title","homepage","domains"]]
# Out:
# C:\Users\matti\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
#                                    original_title  \
# 0                                          Avatar
# 1        Pirates of the Caribbean: At World's End
# 2                                         Spectre
# 3                           The Dark Knight Rises
# 4                                     John Carter
# 5                                    Spider-Man 3
# 6                                         Tangled
# 7                         Avengers: Age of Ultron
# 8          Harry Potter and the Half-Blood Prince
# 9              Batman v Superman: Dawn of Justice
# 10                               Superman Returns
# ...
